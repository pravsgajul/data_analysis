# %%
#importing all required libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df1 = pd.read_csv("winequality-red.csv", sep=';')
df1
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
df2 = pd.read_csv("winequality-white.csv", sep=';')
df2
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 4               7.2              0.23         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
# ...

# %%
#checking for duplicate values in red wine dataset
sum(df1.duplicated())
# Out:
# 240

# %%
#checking for duplicate values in white wine dataset
sum(df2.duplicated())
# Out:
# 937

# %%
#dropping duplicate values
df1.drop_duplicates(inplace=True)
df2.drop_duplicates(inplace=True)

# %%
sum(df1.duplicated())
# Out:
# 0

# %%
sum(df2.duplicated())
# Out:
# 0

# %%
#checking for missing values
df1.isnull().sum(axis=0)
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
df2.isnull().sum(axis=0)
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %% [markdown]
# no missing values

# %% [markdown]
# #### Q1. 1. Merge the datasets and visualize the data by considering its quality label

# %%
#adding a column to indicate colour when the dfs are merged
#number of entries is now total - missing values (removed)

white = np.repeat('white', 3961)
red = np.repeat('red', 1359)
df1['color'] = red
df2['color'] = white

# %%
#appending the rows of the two dfs (merging)

winedf = df1.append(df2, ignore_index=True)
winedf
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4              0.70         0.00             1.9      0.076
# 1               7.8              0.88         0.00             2.6      0.098
# 2               7.8              0.76         0.04             2.3      0.092
# 3              11.2              0.28         0.56             1.9      0.075
# 4               7.4              0.66         0.00             1.8      0.075
# ...             ...               ...          ...             ...        ...
# 5315            6.2              0.21         0.29             1.6      0.039
# 5316            6.6              0.32         0.36             8.0      0.047
# 5317            6.5              0.24         0.19             1.2      0.041
# 5318            5.5              0.29         0.30             1.1      0.022
# 5319            6.0              0.21         0.38             0.8      0.020
#
# ...

# %%
#visualising the data based on quality level
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 5))
ax = winedf['quality'].plot(kind = "hist")

# %% [markdown]
# ## Q2. Sulphates and alcohol

# %%
df3 = winedf[['sulphates', 'alcohol']]
sns.pairplot(df3, height=10, aspect=1)

# %%
df3.corr(method = 'pearson')

# %% [markdown]
# negative correlation, i.e, higher the sulphates, lower the alcohol.

# %% [markdown]
# ## Q3. Correlation between various attributes

# %%
#correlation between various attributes

df4 = winedf[['density', 'total sulfur dioxide', 'residual sugar', 'fixed acidity']]
plt.figure(figsize=(12, 10))
ax = sns.heatmap(df4.corr(), annot=True, fmt='.3g')

# %%
plt.figure(figsize=(10, 15))
ax = sns.pairplot(df4)

# %% [markdown]
# ## Q4. Quality vs alcohol content

# %%
plt.figure(figsize=(15,8))
ax = sns.boxplot(x="quality", y="alcohol", data=winedf)
